# %%
import openai
openai.api_key = "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"

def ask(question):
    response = openai.Completion.create(
        engine="text-davinci-003", prompt=question, max_tokens=1024, n=1, stop=None, temperature=0.7,
    )
    answer = response.choices[0].text.strip()
    return answer

print(ask("give me a joke"))
# Out:
# Q: What did the fish say when he hit the wall?
# A: Dam!

# %%
print(ask("PYTHON AI 語音 API"))
# Out:
# Python AI 語音 API 包括了一系列工具，可以通過自然語言處理（NLP），聲學和語音識別（ASR）等技術來改善語音相關應用的功能。Python AI 語音 API 能夠對聲音信號進行大量的處理，使得語音識別及其他相關應用的發展更加輕鬆。它們也可以提供對語音的分析，以及對於話語的翻譯或者是對不同語言的翻譯等等功能。

# %%
print(ask("Can you speak chinese?"))
# Out:
# ”
#
# “A little bit.”
#
# “Good. Here’s our deal. You don’t speak english, I won’t speak chinese. We’ll keep it simple.”
#
# “Sure.”
#
# “But I have a really important question.”
#
# “What is it?”
#
# “What’s your name?”
#
# “Oh, you don’t speak english.”
#
# “I can speak english and chinese. But you don’t speak chinese and I’m not speaking english.”
#
# “What’s your name?”
#
# “I’m a pilot.”
#
# “What’s your name?”
#
# “I’m an engineer.”
#
# “What’s your name?”
#
# “I’m an engineer.”
#
# “What’s your name?”
#
# “I’m a pilot.”
#
# “What’s your name?”
#
# “I’m an engineer.”
#
# “What’s your name?”
#
# “I’m a pilot.”
#
# “What’s your name?”
#
# “I’m an engineer.”
#
# “What’s your name?”
#
# “I’m a pilot.”
#
# “What’s your name?”
#
# “I’m an engineer.”
#
# “What’s your name?”
#
# “I’m a pilot.”
#
# “What’s your name?”
#
# “I’m an engineer.”
#
# “What’s your name?”
#
# “I’m a pilot.”
#
# “What’s your name?”
#
# “I’m an engineer.”
#
# “What’s your name?”
#
# “I’m a pilot.”
#
# ...
